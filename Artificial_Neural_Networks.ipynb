# %%
import pandas as pd

# %%
df = pd.read_csv('Real_Combine_1.csv')

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3,random_state = 0)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout
# Out:
# Using TensorFlow backend.

# %%
NN_model = Sequential()
NN_model

# %%
#input layer
NN_model.add(Dense(128,kernel_initializer='normal',input_dim = X_train.shape[1],activation = 'relu'))

#Hidden layer
NN_model.add(Dense(256,kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256,kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256,kernel_initializer='normal',activation='relu'))

#Output layer
NN_model.add(Dense(1,kernel_initializer='normal',activation='linear'))

#Compile the network
NN_model.compile(loss = 'mean_absolute_error',optimizer = 'adam',metrics = ['mean_absolute_error'])
NN_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               1152
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 166,017
# Trainable params: 166,017
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_history = NN_model.fit(X_train,y_train,validation_split=0.33,batch_size =10,nb_epoch = 100,verbose = 2)
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   """Entry point for launching an IPython kernel.
# Train on 525 samples, validate on 260 samples
# Epoch 1/100
#  - 0s - loss: 7.0831 - mean_absolute_error: 7.0831 - val_loss: 1.0507 - val_mean_absolute_error: 1.0507
# Epoch 2/100
#  - 0s - loss: 1.1346 - mean_absolute_error: 1.1346 - val_loss: 0.6415 - val_mean_absolute_error: 0.6415
# Epoch 3/100
#  - 0s - loss: 0.8809 - mean_absolute_error: 0.8809 - val_loss: 1.0206 - val_mean_absolute_error: 1.0206
# Epoch 4/100
#  - 0s - loss: 1.0736 - mean_absolute_error: 1.0736 - val_loss: 0.8321 - val_mean_absolute_error: 0.8321
# Epoch 5/100
#  - 0s - loss: 0.8703 - mean_absolute_error: 0.8703 - val_loss: 0.6897 - val_mean_absolute_error: 0.6897
# Epoch 6/100
#  - 0s - loss: 0.7761 - mean_absolute_error: 0.7761 - val_loss: 0.5192 - val_mean_absolute_error: 0.5192
# Epoch 7/100
#  - 0s - loss: 0.7744 - mean_absolute_error: 0.7744 - val_loss: 0.4237 - val_mean_absolute_error: 0.4237
# Epoch 8/100
#  - 0s - loss: 0.6303 - mean_absolute_error: 0.6303 - val_loss: 1.1964 - val_mean_absolute_error: 1.1964
# Epoch 9/100
#  - 0s - loss: 0.7979 - mean_absolute_error: 0.7979 - val_loss: 0.4631 - val_mean_absolute_error: 0.4631
# Epoch 10/100
#  - 0s - loss: 0.8261 - mean_absolute_error: 0.8261 - val_loss: 0.3942 - val_mean_absolute_error: 0.3942
# Epoch 11/100
#  - 0s - loss: 0.8830 - mean_absolute_error: 0.8830 - val_loss: 0.3942 - val_mean_absolute_error: 0.3942
# Epoch 12/100
#  - 0s - loss: 0.6245 - mean_absolute_error: 0.6245 - val_loss: 0.3646 - val_mean_absolute_error: 0.3646
# Epoch 13/100
#  - 0s - loss: 0.4412 - mean_absolute_error: 0.4412 - val_loss: 0.3261 - val_mean_absolute_error: 0.3261
# Epoch 14/100
#  - 0s - loss: 0.4436 - mean_absolute_error: 0.4436 - val_loss: 0.4327 - val_mean_absolute_error: 0.4327
# Epoch 15/100
#  - 0s - loss: 0.5029 - mean_absolute_error: 0.5029 - val_loss: 2.1036 - val_mean_absolute_error: 2.1036
# Epoch 16/100
#  - 0s - loss: 0.9701 - mean_absolute_error: 0.9701 - val_loss: 0.5027 - val_mean_absolute_error: 0.5027
# Epoch 17/100
#  - 0s - loss: 0.4994 - mean_absolute_error: 0.4994 - val_loss: 0.6618 - val_mean_absolute_error: 0.6618
# Epoch 18/100
#  - 0s - loss: 0.6347 - mean_absolute_error: 0.6347 - val_loss: 0.5726 - val_mean_absolute_error: 0.5726
# Epoch 19/100
#  - 0s - loss: 1.5172 - mean_absolute_error: 1.5172 - val_loss: 0.4544 - val_mean_absolute_error: 0.4544
# Epoch 20/100
#  - 0s - loss: 0.6301 - mean_absolute_error: 0.6301 - val_loss: 0.3382 - val_mean_absolute_error: 0.3382
# Epoch 21/100
#  - 0s - loss: 0.5713 - mean_absolute_error: 0.5713 - val_loss: 0.3653 - val_mean_absolute_error: 0.3653
# Epoch 22/100
#  - 0s - loss: 0.4018 - mean_absolute_error: 0.4018 - val_loss: 0.4635 - val_mean_absolute_error: 0.4635
# Epoch 23/100
#  - 0s - loss: 0.4740 - mean_absolute_error: 0.4740 - val_loss: 0.4974 - val_mean_absolute_error: 0.4974
# Epoch 24/100
#  - 0s - loss: 0.4584 - mean_absolute_error: 0.4584 - val_loss: 1.0540 - val_mean_absolute_error: 1.0540
# Epoch 25/100
#  - 0s - loss: 0.6329 - mean_absolute_error: 0.6329 - val_loss: 0.6433 - val_mean_absolute_error: 0.6433
# Epoch 26/100
#  - 0s - loss: 0.3833 - mean_absolute_error: 0.3833 - val_loss: 0.7069 - val_mean_absolute_error: 0.7069
# Epoch 27/100
#  - 0s - loss: 0.5864 - mean_absolute_error: 0.5864 - val_loss: 0.6019 - val_mean_absolute_error: 0.6019
# Epoch 28/100
#  - 0s - loss: 0.2631 - mean_absolute_error: 0.2631 - val_loss: 0.1743 - val_mean_absolute_error: 0.1743
# Epoch 29/100
#  - 0s - loss: 0.4077 - mean_absolute_error: 0.4077 - val_loss: 0.1581 - val_mean_absolute_error: 0.1581
# Epoch 30/100
#  - 0s - loss: 0.7371 - mean_absolute_error: 0.7371 - val_loss: 0.8288 - val_mean_absolute_error: 0.8288
# Epoch 31/100
#  - 0s - loss: 0.6856 - mean_absolute_error: 0.6856 - val_loss: 0.4656 - val_mean_absolute_error: 0.4656
# Epoch 32/100
#  - 0s - loss: 0.3775 - mean_absolute_error: 0.3775 - val_loss: 0.2246 - val_mean_absolute_error: 0.2246
# Epoch 33/100
#  - 0s - loss: 0.4911 - mean_absolute_error: 0.4911 - val_loss: 0.4834 - val_mean_absolute_error: 0.4834
# Epoch 34/100
#  - 0s - loss: 0.4656 - mean_absolute_error: 0.4656 - val_loss: 0.1467 - val_mean_absolute_error: 0.1467
# Epoch 35/100
#  - 0s - loss: 0.5123 - mean_absolute_error: 0.5123 - val_loss: 0.2257 - val_mean_absolute_error: 0.2257
# Epoch 36/100
#  - 0s - loss: 0.5465 - mean_absolute_error: 0.5465 - val_loss: 0.1650 - val_mean_absolute_error: 0.1650
# Epoch 37/100
#  - 0s - loss: 0.4443 - mean_absolute_error: 0.4443 - val_loss: 0.6780 - val_mean_absolute_error: 0.6780
# Epoch 38/100
#  - 0s - loss: 0.6890 - mean_absolute_error: 0.6890 - val_loss: 1.1664 - val_mean_absolute_error: 1.1664
# Epoch 39/100
#  - 0s - loss: 0.4881 - mean_absolute_error: 0.4881 - val_loss: 0.6363 - val_mean_absolute_error: 0.6363
# Epoch 40/100
#  - 0s - loss: 0.6097 - mean_absolute_error: 0.6097 - val_loss: 0.1449 - val_mean_absolute_error: 0.1449
# Epoch 41/100
#  - 0s - loss: 0.4949 - mean_absolute_error: 0.4949 - val_loss: 0.1400 - val_mean_absolute_error: 0.1400
# Epoch 42/100
#  - 0s - loss: 0.4006 - mean_absolute_error: 0.4006 - val_loss: 0.1309 - val_mean_absolute_error: 0.1309
# Epoch 43/100
#  - 0s - loss: 0.3864 - mean_absolute_error: 0.3864 - val_loss: 0.7439 - val_mean_absolute_error: 0.7439
# Epoch 44/100
#  - 0s - loss: 0.3323 - mean_absolute_error: 0.3323 - val_loss: 0.3549 - val_mean_absolute_error: 0.3549
# Epoch 45/100
#  - 0s - loss: 0.3312 - mean_absolute_error: 0.3312 - val_loss: 0.7357 - val_mean_absolute_error: 0.7357
# Epoch 46/100
#  - 0s - loss: 0.4062 - mean_absolute_error: 0.4062 - val_loss: 0.2156 - val_mean_absolute_error: 0.2156
# Epoch 47/100
#  - 0s - loss: 0.2921 - mean_absolute_error: 0.2921 - val_loss: 0.5956 - val_mean_absolute_error: 0.5956
# Epoch 48/100
#  - 0s - loss: 0.3820 - mean_absolute_error: 0.3820 - val_loss: 0.2352 - val_mean_absolute_error: 0.2352
# Epoch 49/100
#  - 0s - loss: 0.5155 - mean_absolute_error: 0.5155 - val_loss: 1.4262 - val_mean_absolute_error: 1.4262
# Epoch 50/100
#  - 0s - loss: 1.1848 - mean_absolute_error: 1.1848 - val_loss: 0.7177 - val_mean_absolute_error: 0.7177
# Epoch 51/100
#  - 0s - loss: 0.5016 - mean_absolute_error: 0.5016 - val_loss: 0.1267 - val_mean_absolute_error: 0.1267
# Epoch 52/100
#  - 0s - loss: 0.2850 - mean_absolute_error: 0.2850 - val_loss: 1.3605 - val_mean_absolute_error: 1.3605
# Epoch 53/100
#  - 0s - loss: 0.4764 - mean_absolute_error: 0.4764 - val_loss: 0.8796 - val_mean_absolute_error: 0.8796
# Epoch 54/100
#  - 0s - loss: 0.7083 - mean_absolute_error: 0.7083 - val_loss: 0.4203 - val_mean_absolute_error: 0.4203
# Epoch 55/100
#  - 0s - loss: 0.4226 - mean_absolute_error: 0.4226 - val_loss: 0.8084 - val_mean_absolute_error: 0.8084
# Epoch 56/100
#  - 0s - loss: 0.4230 - mean_absolute_error: 0.4230 - val_loss: 0.6749 - val_mean_absolute_error: 0.6749
# Epoch 57/100
#  - 0s - loss: 0.3973 - mean_absolute_error: 0.3973 - val_loss: 0.2713 - val_mean_absolute_error: 0.2713
# Epoch 58/100
#  - 0s - loss: 0.3924 - mean_absolute_error: 0.3924 - val_loss: 0.1065 - val_mean_absolute_error: 0.1065
# Epoch 59/100
#  - 0s - loss: 0.4156 - mean_absolute_error: 0.4156 - val_loss: 0.6018 - val_mean_absolute_error: 0.6018
# Epoch 60/100
#  - 0s - loss: 0.3860 - mean_absolute_error: 0.3860 - val_loss: 0.1411 - val_mean_absolute_error: 0.1411
# Epoch 61/100
#  - 0s - loss: 0.3943 - mean_absolute_error: 0.3943 - val_loss: 0.9363 - val_mean_absolute_error: 0.9363
# Epoch 62/100
#  - 0s - loss: 0.3569 - mean_absolute_error: 0.3569 - val_loss: 0.3889 - val_mean_absolute_error: 0.3889
# Epoch 63/100
#  - 0s - loss: 0.4588 - mean_absolute_error: 0.4588 - val_loss: 0.2941 - val_mean_absolute_error: 0.2941
# Epoch 64/100
#  - 0s - loss: 0.2967 - mean_absolute_error: 0.2967 - val_loss: 1.1604 - val_mean_absolute_error: 1.1604
# Epoch 65/100
#  - 0s - loss: 0.5347 - mean_absolute_error: 0.5347 - val_loss: 0.3420 - val_mean_absolute_error: 0.3420
# Epoch 66/100
#  - 0s - loss: 0.3405 - mean_absolute_error: 0.3405 - val_loss: 0.7886 - val_mean_absolute_error: 0.7886
# Epoch 67/100
#  - 0s - loss: 0.4484 - mean_absolute_error: 0.4484 - val_loss: 0.2335 - val_mean_absolute_error: 0.2335
# Epoch 68/100
#  - 0s - loss: 0.2378 - mean_absolute_error: 0.2378 - val_loss: 0.5896 - val_mean_absolute_error: 0.5896
# Epoch 69/100
#  - 0s - loss: 0.3679 - mean_absolute_error: 0.3679 - val_loss: 0.9155 - val_mean_absolute_error: 0.9155
# Epoch 70/100
#  - 0s - loss: 0.4539 - mean_absolute_error: 0.4539 - val_loss: 0.3225 - val_mean_absolute_error: 0.3225
# Epoch 71/100
#  - 0s - loss: 0.3038 - mean_absolute_error: 0.3038 - val_loss: 0.3785 - val_mean_absolute_error: 0.3785
# Epoch 72/100
#  - 0s - loss: 0.4821 - mean_absolute_error: 0.4821 - val_loss: 0.5222 - val_mean_absolute_error: 0.5222
# Epoch 73/100
#  - 0s - loss: 0.5232 - mean_absolute_error: 0.5232 - val_loss: 0.1305 - val_mean_absolute_error: 0.1305
# Epoch 74/100
#  - 0s - loss: 0.2926 - mean_absolute_error: 0.2926 - val_loss: 0.1839 - val_mean_absolute_error: 0.1839
# Epoch 75/100
#  - 0s - loss: 0.3106 - mean_absolute_error: 0.3106 - val_loss: 0.1807 - val_mean_absolute_error: 0.1807
# Epoch 76/100
#  - 0s - loss: 0.1988 - mean_absolute_error: 0.1988 - val_loss: 0.0939 - val_mean_absolute_error: 0.0939
# Epoch 77/100
#  - 0s - loss: 0.5867 - mean_absolute_error: 0.5867 - val_loss: 0.2219 - val_mean_absolute_error: 0.2219
# Epoch 78/100
#  - 0s - loss: 0.5277 - mean_absolute_error: 0.5277 - val_loss: 0.4956 - val_mean_absolute_error: 0.4956
# Epoch 79/100
#  - 0s - loss: 0.6303 - mean_absolute_error: 0.6303 - val_loss: 0.2119 - val_mean_absolute_error: 0.2119
# Epoch 80/100
#  - 0s - loss: 0.3270 - mean_absolute_error: 0.3270 - val_loss: 0.1150 - val_mean_absolute_error: 0.1150
# Epoch 81/100
#  - 0s - loss: 0.3002 - mean_absolute_error: 0.3002 - val_loss: 0.2342 - val_mean_absolute_error: 0.2342
# Epoch 82/100
#  - 0s - loss: 0.4080 - mean_absolute_error: 0.4080 - val_loss: 0.1627 - val_mean_absolute_error: 0.1627
# Epoch 83/100
#  - 0s - loss: 0.5033 - mean_absolute_error: 0.5033 - val_loss: 0.7873 - val_mean_absolute_error: 0.7873
# Epoch 84/100
#  - 0s - loss: 0.4056 - mean_absolute_error: 0.4056 - val_loss: 0.0694 - val_mean_absolute_error: 0.0694
# Epoch 85/100
#  - 0s - loss: 0.6982 - mean_absolute_error: 0.6982 - val_loss: 0.4936 - val_mean_absolute_error: 0.4936
# Epoch 86/100
#  - 0s - loss: 0.4594 - mean_absolute_error: 0.4594 - val_loss: 0.2471 - val_mean_absolute_error: 0.2471
# Epoch 87/100
#  - 0s - loss: 0.3437 - mean_absolute_error: 0.3437 - val_loss: 0.3576 - val_mean_absolute_error: 0.3576
# Epoch 88/100
#  - 0s - loss: 0.2324 - mean_absolute_error: 0.2324 - val_loss: 0.3890 - val_mean_absolute_error: 0.3890
# Epoch 89/100
#  - 0s - loss: 0.2178 - mean_absolute_error: 0.2178 - val_loss: 0.1299 - val_mean_absolute_error: 0.1299
# Epoch 90/100
#  - 0s - loss: 0.2903 - mean_absolute_error: 0.2903 - val_loss: 0.2682 - val_mean_absolute_error: 0.2682
# Epoch 91/100
#  - 0s - loss: 0.5134 - mean_absolute_error: 0.5134 - val_loss: 0.7006 - val_mean_absolute_error: 0.7006
# Epoch 92/100
#  - 0s - loss: 0.2827 - mean_absolute_error: 0.2827 - val_loss: 0.1162 - val_mean_absolute_error: 0.1162
# Epoch 93/100
#  - 0s - loss: 0.4236 - mean_absolute_error: 0.4236 - val_loss: 0.9174 - val_mean_absolute_error: 0.9174
# Epoch 94/100
#  - 0s - loss: 0.5677 - mean_absolute_error: 0.5677 - val_loss: 0.3099 - val_mean_absolute_error: 0.3099
# Epoch 95/100
#  - 0s - loss: 0.3377 - mean_absolute_error: 0.3377 - val_loss: 0.5358 - val_mean_absolute_error: 0.5358
# Epoch 96/100
#  - 0s - loss: 0.4368 - mean_absolute_error: 0.4368 - val_loss: 0.9410 - val_mean_absolute_error: 0.9410
# Epoch 97/100
#  - 0s - loss: 0.4589 - mean_absolute_error: 0.4589 - val_loss: 0.1139 - val_mean_absolute_error: 0.1139
# Epoch 98/100
#  - 0s - loss: 0.4060 - mean_absolute_error: 0.4060 - val_loss: 0.3351 - val_mean_absolute_error: 0.3351
# Epoch 99/100
#  - 0s - loss: 0.2469 - mean_absolute_error: 0.2469 - val_loss: 0.0856 - val_mean_absolute_error: 0.0856
# Epoch 100/100
#  - 0s - loss: 0.5397 - mean_absolute_error: 0.5397 - val_loss: 0.3174 - val_mean_absolute_error: 0.3174

# %%
prediction = NN_model.predict(X_test)

# %%
prediction
# Out:
# array([[3.2753151e+01],
#        [3.1043306e+01],
#        [3.3069328e+01],
#        [2.8730598e+01],
#        [3.1775749e+01],
#        [2.9736849e+01],
#        [2.8317793e+01],
#        [3.1621243e+01],
#        [3.0945021e+01],
#        [2.6664501e+01],
#        [3.3331905e+01],
#        [3.3528717e+01],
#        [2.5907352e+01],
#        [3.3676971e+01],
#        [2.8079079e+01],
#        [2.8640406e+01],
#        [3.5421516e+01],
#        [3.2123695e+01],
#        [2.6674078e+01],
#        [3.7286270e+01],
#        [3.6701344e+01],
#        [3.2134266e+01],
#        [3.1279703e+01],
#        [3.1234301e+01],
#        [3.0390287e+01],
#        [3.1116377e+01],
#        [3.4991913e+01],
#        [3.1475811e+01],
#        [2.8397104e+01],
#        [3.1977245e+01],
#        [2.9823275e+01],
#        [2.8409292e+01],
#        [2.7933973e+01],
#        [2.7623194e+01],
#        [2.5179987e+01],
#        [2.8524141e+01],
#        [3.0461906e+01],
#        [3.1797132e+01],
#        [3.0417732e+01],
#        [3.4477097e+01],
#        [2.9212797e+01],
#        [2.7595831e+01],
#        [3.2547623e+01],
#        [3.1507029e+01],
#        [2.5237345e+01],
#        [3.0132750e+01],
#        [2.9490789e+01],
#        [3.4068298e+01],
#        [3.1909494e+01],
#        [3.0524027e+01],
#        [2.8591236e+01],
#        [3.1668577e+01],
#        [3.2040028e+01],
#        [2.7736753e+01],
#        [2.9188478e+01],
#        [2.7492868e+01],
#        [2.9115705e+01],
#        [2.8378084e+01],
#        [1.4341254e-02],
#        [2.8697298e+01],
#        [3.4955967e+01],
#        [2.9727201e+01],
#        [2.9636690e+01],
#        [2.9722033e+01],
#        [3.5940414e+01],
#        [2.9222589e+01],
#        [3.0564089e+01],
#        [2.8111059e+01],
#        [2.8329346e+01],
#        [3.0817883e+01],
#        [3.3492203e+01],
#        [3.3293636e+01],
#        [2.7517414e+01],
#        [2.9679293e+01],
#        [3.6063591e+01],
#        [3.3885651e+01],
#        [2.8469801e+01],
#        [2.9434216e+01],
#        [3.5325371e+01],
#        [3.4791023e+01],
#        [2.9835367e+01],
#        [3.2444313e+01],
#        [3.3105652e+01],
#        [2.9138008e+01],
#        [3.0645737e+01],
#        [3.3855789e+01],
#        [2.9321751e+01],
#        [3.0512083e+01],
#        [2.9626001e+01],
#        [3.4111908e+01],
#        [2.9420107e+01],
#        [2.9162291e+01],
#        [2.9414690e+01],
#        [2.6954376e+01],
#        [3.4000732e+01],
#        [2.7164461e+01],
#        [3.0927519e+01],
#        [3.0297604e+01],
#        [3.2419106e+01],
#        [2.8225290e+01],
#        [2.9608061e+01],
#        [2.9486624e+01],
#        [3.1224768e+01],
#        [3.1345499e+01],
#        [3.5031204e+01],
#        [3.0501497e+01],
#        [2.8214724e+01]], dtype=float32)

# %%
y_test.values.reshape(-1,1)
# Out:
# array([[32.5],
#        [30.8],
#        [32.7],
#        [28.3],
#        [31.6],
#        [29.5],
#        [28.1],
#        [31.2],
#        [30.7],
#        [26.4],
#        [33. ],
#        [33.4],
#        [25.6],
#        [33.5],
#        [27.7],
#        [28.2],
#        [35.1],
#        [31.8],
#        [26.4],
#        [36.8],
#        [36.3],
#        [31.8],
#        [31. ],
#        [30.8],
#        [30.1],
#        [30.9],
#        [34.7],
#        [31.2],
#        [28.2],
#        [31.7],
#        [29.6],
#        [28. ],
#        [27.6],
#        [27.2],
#        [24.8],
#        [28.3],
#        [30.1],
#        [31.6],
#        [29.9],
#        [34. ],
#        [28.9],
#        [27.3],
#        [32.2],
#        [31.2],
#        [24.9],
#        [29.7],
#        [29.2],
#        [33.8],
#        [31.6],
#        [30.3],
#        [28.3],
#        [31.3],
#        [31.7],
#        [27.4],
#        [29. ],
#        [27.2],
#        [29. ],
#        [28. ],
#        [ 0. ],
#        [28.4],
#        [34.6],
#        [29.6],
#        [29.4],
#        [29.3],
#        [35.5],
#        [28.9],
#        [30.3],
#        [27.8],
#        [28. ],
#        [30.6],
#        [33.3],
#        [33. ],
#        [27.2],
#        [29.3],
#        [35.5],
#        [33.8],
#        [28.3],
#        [29. ],
#        [35. ],
#        [34.6],
#        [29.5],
#        [32.1],
#        [32.7],
#        [28.8],
#        [30.4],
#        [33.4],
#        [29. ],
#        [30.2],
#        [29.3],
#        [34. ],
#        [29.2],
#        [28.9],
#        [29.1],
#        [26.5],
#        [33.8],
#        [26.9],
#        [30.6],
#        [30. ],
#        [32.1],
#        [28. ],
#        [29.4],
#        [29.1],
#        [30.9],
#        [30.3],
#        [31.4],
#        [29.4],
#        [27.4],
#        [28.3],
#        [27.6],
#        [29. ],
#        [31. ],
#        [29.6],
#        [30.3],
#        [28.1],
#        [28.7],
#        [28.5],
#        [34.5],
#        [33.4],
#        [35.3],
#        [29.3],
#        [35. ],
#        [28.9],
#        [26.4],
#        [33.6],
#        [34.5],
#        [29.5],
#        [26.9],
#        [31.6],
#        [34.6],
#        [28. ],
#        [30.3],
#        [28. ],
#        [32.8],
#        [30.2],
#        [28.5],
#        [35.9],
#        [27.8],
#        [27.5],
#        [31.3],
#        [32.5],
#        [26.5],
#        [27. ],
#        [27.3],
#        [29.8],
#        [29.8],
#        [32.6],
#        [35. ],
#        [31.2],
#        [35. ],
#        [30.6],
#        [35.8],
#        [26.6],
#        [30.6],
#        [30.5],
#        [30.2],
#        [28.5],
#        [35.8],
#        [30.1],
#        [28.5],
#        [31.5],
#        [35.4],
#        [28.9],
#        [28.1],
#        [28.7],
#        [32. ],
#        [34.5],
#        [27.2],
#        [34.6],
#        [30.9],
#        [29. ],
#        [30.9],
#        [34. ],
#        [29.2],
#        [27.4],
#        [28.2],
#        [29.9],
#        [29.5],
#        [34.4],
#        [31.3],
#        [29.9],
#        [28.6],
#        [27.2],
#        [30.2],
#        [29.1],
#        [30.7],
#        [36.6],
#        [30.5],
#        [28.1],
#        [31.2],
#        [34.7],
#        [28. ],
#        [30.3],
#        [29. ],
#        [29.8],
#        [28.5],
#        [34.8],
#        [28.2],
#        [30.2],
#        [31.6],
#        [28.6],
#        [31.9],
#        [28.8],
#        [30.6],
#        [ 0. ],
#        [30.6],
#        [31.8],
#        [29.2],
#        [31.6],
#        [28.8],
#        [29.3],
#        [33.5],
#        [30.8],
#        [29.4],
#        [30.7],
#        [26.4],
#        [34.3],
#        [30.4],
#        [28.2],
#        [30.4],
#        [30.3],
#        [29.8],
#        [30.2],
#        [30.4],
#        [27.9],
#        [33.8],
#        [28.8],
#        [33. ],
#        [29.5],
#        [25. ],
#        [28. ],
#        [27.2],
#        [27.5],
#        [29.9],
#        [30.4],
#        [35.1],
#        [34. ],
#        [28.2],
#        [29. ],
#        [35.8],
#        [30.4],
#        [31.2],
#        [30.1],
#        [29.3],
#        [27.7],
#        [27.7],
#        [35.1],
#        [31.5],
#        [33.8],
#        [31.1],
#        [29. ],
#        [28.1],
#        [27.8],
#        [29. ],
#        [31.2],
#        [26.5],
#        [35.6],
#        [30.7],
#        [28.2],
#        [31.6],
#        [30.7],
#        [28.4],
#        [27.2],
#        [32.1],
#        [30.3],
#        [28.7],
#        [27.4],
#        [30.8],
#        [28.9],
#        [30.7],
#        [29. ],
#        [30.3],
#        [33.5],
#        [30.6],
#        [32.4],
#        [26.5],
#        [25.8],
#        [27. ],
#        [28.3],
#        [28.9],
#        [31.4],
#        [30.9],
#        [35. ],
#        [32.4],
#        [28.3],
#        [28. ],
#        [37.4],
#        [27.2],
#        [33.4],
#        [28. ],
#        [35.9],
#        [31.2],
#        [33.5],
#        [30. ],
#        [32.2],
#        [33.1],
#        [28. ],
#        [29.2],
#        [31.5],
#        [28.2],
#        [33.6],
#        [31. ],
#        [31.3],
#        [25. ],
#        [32.1],
#        [35.3],
#        [29.2],
#        [29.3],
#        [ 0. ],
#        [28.4],
#        [35.5],
#        [35.6],
#        [29. ],
#        [25.2],
#        [32.2],
#        [30. ],
#        [30.1],
#        [28.8],
#        [26.7],
#        [26. ],
#        [32. ],
#        [31.4],
#        [31.2],
#        [29.7],
#        [30. ],
#        [29. ],
#        [34. ],
#        [29.4],
#        [34.4],
#        [29.4],
#        [28.5],
#        [30.3],
#        [30.4],
#        [27.8],
#        [31. ],
#        [34.6],
#        [30.2],
#        [27.9]])

# %%
import seaborn as sns
sns.distplot(y_test.values.reshape(-1,1) - prediction)
# Out:
# <AxesSubplot:>

# %%
from sklearn import metrics
import numpy as np
print(metrics.mean_absolute_error(y_test,prediction))
print(metrics.mean_squared_error(y_test,prediction))
print(np.sqrt(metrics.mean_squared_error(y_test,prediction)))
# Out:
# 0.3108799696211823
# 0.10667807450364933
# 0.32661609651645973
